# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\POOJA\Downloads\Annexure 4- List of QHEIs identified for PM-Vidyalaxmi Schemes 05062025.xlsx")

# %%
df.head()
# Out:
#   LIST OF PM-VIDYALAXMI INSTITUTIONS (860)  Unnamed: 1  \
# 0                                  S.\nNO.  AISHE CODE
# 1                                        1      U-1108
# 2                                        2      U-1114
# 3                                        3      U-1218
# 4                                        4      U-1057
#
#                                           Unnamed: 2    Unnamed: 3  \
# 0                                     INSTITUTE NAME      CATEGORY
# 1  ALL INDIA INSTITUTE OF MEDICAL SCIENCE  BIBINAGAR  PMVL-UTKARSH
# 2    ALL INDIA INSTITUTE OF MEDICAL SCIENCE BHATINDA  PMVL-UTKARSH
# 3    ALL INDIA INSTITUTE OF MEDICAL SCIENCE BILASPUR  PMVL-UTKARSH
# 4     ALL INDIA INSTITUTE OF MEDICAL SCIENCE DEOGHAR  PMVL-UTKARSH
#
#          Unnamed: 4  Unnamed: 5
# 0             STATE      CIRCLE
# 1         TELANGANA   HYDERABAD
# 2            PUNJAB  CHANDIGARH
# 3  HIMACHAL PRADESH  CHANDIGARH
# 4         JHARKHAND       PATNA

# %%
df['Unnamed: 4']
# Out:
# 0                 STATE
# 1             TELANGANA
# 2                PUNJAB
# 3      HIMACHAL PRADESH
# 4             JHARKHAND
#              ...
# 856          TAMIL NADU
# 857         MAHARASHTRA
# 858           KARNATAKA
# 859      ANDHRA PRADESH
# 860               DELHI
# Name: Unnamed: 4, Length: 861, dtype: object

# %%
df['Unnamed: 4'].unique()
# Out:
# array(['STATE', 'TELANGANA', 'PUNJAB', 'HIMACHAL PRADESH', 'JHARKHAND',
#        'UTTAR PRADESH', 'JAMMU AND KASHMIR', 'WEST BENGAL', 'GUJARAT',
#        'MADHYA PRADESH', 'ODISHA', 'DELHI', 'RAJASTHAN', 'TAMIL NADU',
#        'MAHARASHTRA', 'BIHAR', 'CHHATTISGARH', 'UTTARAKHAND', 'ASSAM',
#        'ANDHRA PRADESH', 'KARNATAKA', 'KERALA', 'HARYANA', 'MEGHALAYA',
#        'GOA', 'MANIPUR', 'DADRA & NAGAR HAVELI AND DAMAN\n& DIU',
#        'CHANDIGARH', 'TRIPURA', 'PUDUCHERRY', 'ARUNACHAL PRADESH',
#        'MIZORAM', 'NAGALAND', 'SIKKIM', 'LADAKH',
#        'DADRA & NAGAR\nHAVELI AND DAMAN & DIU'], dtype=object)

# %%
kar_clg = df[df['Unnamed: 4']=='KARNATAKA'].sort_values[]

# %%
kar_dvg_clg = []
z = ['DENTAL' for df['Unnamed: 2'] in kar_clg['Unnamed: 2']]

# %%
z = [str('DENTAL') for df['Unnamed: 2'] in kar_clg['Unnamed: 2']]

# %%
z.index
# Out:
# <function list.index(value, start=0, stop=9223372036854775807, /)>

# %%
kar_clg
# Out:
#     LIST OF PM-VIDYALAXMI INSTITUTIONS (860) Unnamed: 1  \
# 268                                      268    C-19320
# 271                                      271    C-40354
# 288                                      288    C-17415
# 289                                      289     U-0213
# 308                                      308     U-0215
# ..                                       ...        ...
# 830                                      830     U-0244
# 834                                      834     U-0248
# 835                                      835     U-0246
# 267                                      267     U-0249
# 858                                      858     C-8528
#
#                                             Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 268   A.B.SHETTY MEMORIAL INSTITUTE OF DENTAL SCIENCES   PMVL-UDAY  KARNATAKA
# 271            ACHARYA & B M REDDY COLLEGE OF PHARMACY   PMVL-UDAY  KARNATAKA
# ...

# %%
kar_clg['Unnamed: 2'] if 'DENTAL' in df['Unnamed: 2'].values else None

# %%
kar_clg
# Out:
#     LIST OF PM-VIDYALAXMI INSTITUTIONS (860) Unnamed: 1  \
# 268                                      268    C-19320
# 271                                      271    C-40354
# 288                                      288    C-17415
# 289                                      289     U-0213
# 308                                      308     U-0215
# ..                                       ...        ...
# 830                                      830     U-0244
# 834                                      834     U-0248
# 835                                      835     U-0246
# 267                                      267     U-0249
# 858                                      858     C-8528
#
#                                             Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 268   A.B.SHETTY MEMORIAL INSTITUTE OF DENTAL SCIENCES   PMVL-UDAY  KARNATAKA
# 271            ACHARYA & B M REDDY COLLEGE OF PHARMACY   PMVL-UDAY  KARNATAKA
# ...
